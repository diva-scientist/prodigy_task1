# %%
import matplotlib.pyplot as plt
import numpy as np
import random

# %%
# Sample data - replace this with your own dataset
ml_students_age = np.random.randint(18,45, (100))
py_students_age = np.random.randint(15,40, (100))

# %%
print(ml_students_age)
print(py_students_age)
# Out:
# [19 32 20 23 21 29 41 25 22 21 38 40 28 30 39 36 29 38 43 32 42 29 26 36
#  18 22 20 40 34 37 28 28 19 30 39 37 36 41 26 36 27 33 18 31 30 25 24 31
#  24 31 29 31 23 39 37 19 30 29 36 20 34 36 24 39 39 42 33 36 40 28 27 36
#  42 26 42 41 21 22 42 26 43 22 25 43 28 41 36 42 42 39 22 25 26 29 29 42
#  33 31 24 39]
# [32 21 38 19 16 16 19 16 35 38 28 22 34 16 32 33 18 35 31 20 32 32 32 27
#  24 29 30 16 19 26 16 24 30 32 31 16 27 29 30 35 24 38 15 27 26 33 17 32
#  21 39 23 36 37 26 16 16 18 17 38 30 30 26 33 17 34 31 32 22 33 23 19 29
#  36 24 35 17 25 22 18 32 22 32 19 24 24 26 25 20 23 36 36 25 32 29 37 32
#  21 20 38 22]

# %%
# from matplotlib import style
# style.use("ggplot")
bins = [15,20,25,30,35,40,45]
plt.figure(figsize = (16,9))

plt.hist([ml_students_age, py_students_age], bins, rwidth=0.8, histtype = "bar",
         orientation='vertical', color = ["m", "y"], label = ["ML Student", "Py Student"])

#plt.hist(py_students_age, bins, rwidth=0.8, histtype = "bar",
#         orientation='vertical', color = "y", label = "Py Student")

plt.title("ML & Py Students age histograms")
plt.xlabel("Students age cotegory")
plt.ylabel("No. Students age")
plt.legend()
plt.show()

# %% [markdown]
# **Thank You**
